# %% [markdown]
# # Task 1
# #### Assume a file with content of the form:
#
# student information in form name: age, phone number:
#
# - Per:24,12345678
#
# - Kari:23,23456789
#
# - Ole:24,34567891
#
# Write a program which generates a dictionary for each student which incorporates their name, age, and phone number. Store this dictionary in a list and print it out. Your program should:
#
# - Read the file.
# - Store information about each student in a dictionary of their name, age and phone number.
# - Store the dictionaries of all the students in a list.

# %%
print('f')
